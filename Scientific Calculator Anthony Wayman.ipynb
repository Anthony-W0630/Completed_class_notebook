# %%
import math

class Calculator():
    def __init__(self, input1, input2):
        self.input1=input1
        self.input2=input2
        
    def add(num1, num2):
        print("Addition", num1+num2)
            
    def subtraction(num1, num2):
        print("Subtraction", num1-num2)
            
    def multiplication (num1, num2):
        print("Multiplication", num1*num2)
            
    def division(num1, num2):
        print("division", num1/num2)
            
    def sqrt(num1):
        print("Sqrt: ", math.sqrt(num1))
        
    def power(root, exp):
        print("Power: ", root**exp)
        
    def log(x,base):
        print("log: ", math.log(x,base))
        
    def natlog(x):
        print("Natural Log: ", math.log1p(x))
    
    def sin(x):
        print("sin: ", math.sin(x))
    
    def cos(x):
        print("cos: ", math.cos(x))
    
    def tan(x):
        print("cos: ", math.tan(x))
    
    def arcsin(x):
        prit("arcsin: ", math.asin(x))
    
    def arccos(x):
        print("arccos: ", math.acos(x))
    
    def arctan(x):
        print("arctan: ", math.atan(x))
        
    def degrees(x):
        print("Radians to degrees: ", math.degrees(x))
        
    def remainder(num1, num2):
        print("The remainder: ", math.remainder(num1, num2))
        
    def radians(x):
        print("Degrees to radians: ", math.radians(x))
        
    def pi():
        print("Pi: ", math.pi)
        
    def e():
          print("e: ", math.e())
            
            
while True:
    print("1: Addition")
    print("2: Subtraction")
    print("3: Multiplication")
    print("4: Division")
    print("5: Sqrt")
    print("6: Power")
    print("7: Log")
    print("8: Natural Log")
    print("9: sin")
    print("10: cos")
    print("11: tan")
    print("12: arcsin")
    print("13: arccos")
    print("14: arctan")
    print("15: Degrees")
    print("16: Remainder")
    print("17: Radians")
    print("18: Pi")
    print("19: e")
    print("20: Exit")
    choice= int(input("Enter your choice (1-20): "))
    
    if choice==1:
        num1=int(input("Enter the 1st number: "))
        num2=int(input("Enter the 2nd number: "))
        Calculator.add(num1, num2)
    elif choice==2:
        num1=int(input("Enter the 1st number: "))
        num2=int(input("Enter the 2nd number: "))
        Calculator.subtraction(num1, num2)
    elif choice==3:
        num1=int(input("Enter the 1st number: "))
        num2=int(input("Enter the 2nd number: "))
        Calculator.multiplication(num1, num2)
    elif choice==4:
        num1=int(input("Enter the 1st number: "))
        num2=int(input("Enter the 2nd number: "))
        Calculator.division(num1, num2)
    elif choice==5:
        num1=int(input("Enter the 1st number: "))
        Calculator.sqrt(num1)
    elif choice==6:
        root=int(input("Enter the root: "))
        exp=int(input("Enter the exponent: "))
        Calculator.power(num1,exp)
    elif choice==7:
        x=int(input("Enter the number: "))
        base=int(input("Enter the base: "))
        Calculator.log(x,base)
    elif choice==8:
        x=int(input("Enter the number: "))
        Calculator.natlog(x)
    elif choice==9:
        x=int(input("Enter the number: "))
        Calculator.sin(x)
    elif choice==10:
        x=int(input("Enter the number: "))
        Calculator.cos(x)
    elif choice==11:
        x=int(input("Enter the number: "))
        Calculator.tan(x)
    elif choice==12:
        x=int(input("Enter the number: "))
        Calculator.arcsin(x)
    elif choice==13:
        x=int(input("Enter the number: "))
        Calculator.arccos(x)
    elif choice==14:
        x=int(input("Enter the number: "))
        Calculator.arctan(x)
    elif choice==15:
        x=int(input("Enter the number: "))
        Calculator.degrees(num1,exp)
    elif choice==16:
        num1=int(input("Enter the 1st number: "))
        num2=int(input("Enter the 2nd number: "))
        Calculator.remainder(num1,exp)
    elif choice==17:
        x=int(input("Enter the number: "))
        Calculator.radians(x)
    elif choice==18:
        Calculator.pi()
    elif choice==19:
        print("e: ", Calculator.e())
        
        
        if num2==0:
            print("infinity")
            
        else:
            Calculator.division(num1, num2)
            
    elif choice==20:
        break
    else:
        print("Wrong choice. choose a number between 1-5")
# Out:
# 1: Addition
# 2: Subtraction
# 3: Multiplication
# 4: Division
# 5: Sqrt
# 6: Power
# 7: Log
# 8: Natural Log
# 9: sin
# 10: cos
# 11: tan
# 12: arcsin
# 13: arccos
# 14: arctan
# 15: Degrees
# 16: Remainder
# 17: Radians
# 18: Pi
# 19: e
# 20: Exit
